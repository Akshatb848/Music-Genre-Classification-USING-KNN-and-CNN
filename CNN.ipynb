# %%
import kagglehub

# Download the latest version of the dataset
path = kagglehub.dataset_download("andradaolteanu/gtzan-dataset-music-genre-classification")

# Print the path where the dataset is saved
print("Path to dataset files:", path)
# Out:
# Path to dataset files: /kaggle/input/gtzan-dataset-music-genre-classification

# %%
import numpy as np
from scipy.io import wavfile
import librosa

def safe_load_wav(audio_path, duration=30, sr=22050):
    try:
        # Read using scipy
        orig_sr, audio = wavfile.read(audio_path)
        audio = audio.astype(np.float32)

        # Resample if needed
        if orig_sr != sr:
            audio = librosa.resample(audio, orig_sr, sr)

        # Trim or pad to fixed length
        max_len = duration * sr
        if len(audio) > max_len:
            audio = audio[:max_len]
        elif len(audio) < max_len:
            audio = np.pad(audio, (0, max_len - len(audio)))

        return audio, sr
    except Exception as e:
        print(f"Failed to load {audio_path}: {e}")
        return None, None

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tqdm import tqdm

image_dir = "/kaggle/input/gtzan-dataset-music-genre-classification/Data/images_original"
genres = os.listdir(image_dir)

img_height, img_width = 128, 128

X, y = [], []

for genre in genres:
    genre_path = os.path.join(image_dir, genre)
    for img_file in tqdm(os.listdir(genre_path), desc=f"Loading {genre}"):
        try:
            img_path = os.path.join(genre_path, img_file)
            img = load_img(img_path, target_size=(img_height, img_width))
            img_array = img_to_array(img) / 255.0
            X.append(img_array)
            y.append(genre)
        except Exception as e:
            print(f"Skipped {img_path}: {e}")

X = np.array(X)
y = np.array(y)

le = LabelEncoder()
y_encoded = le.fit_transform(y)
y_categorical = to_categorical(y_encoded)

X_train, X_test, y_train, y_test = train_test_split(X, y_categorical, test_size=0.2, random_state=42)

model = Sequential([
    Input(shape=(img_height, img_width, 3)),
    Conv2D(32, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Flatten(),
    Dense(128, activation='relu'),
    Dropout(0.3),
    Dense(10, activation='softmax')
])

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

history = model.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_test, y_test))

test_loss, test_acc = model.evaluate(X_test, y_test)
print(f"✅ Test accuracy: {test_acc:.4f}")
# Out:
# Loading disco: 100%|██████████| 100/100 [00:01<00:00, 97.86it/s]
# Loading metal: 100%|██████████| 100/100 [00:00<00:00, 103.96it/s]
# Loading reggae: 100%|██████████| 100/100 [00:00<00:00, 108.40it/s]
# Loading blues: 100%|██████████| 100/100 [00:00<00:00, 114.65it/s]
# Loading rock: 100%|██████████| 100/100 [00:00<00:00, 102.34it/s]
# Loading classical: 100%|██████████| 100/100 [00:00<00:00, 114.41it/s]
# Loading jazz: 100%|██████████| 99/99 [00:00<00:00, 111.58it/s]
# Loading hiphop: 100%|██████████| 100/100 [00:00<00:00, 112.99it/s]
# Loading country: 100%|██████████| 100/100 [00:00<00:00, 107.24it/s]
# Loading pop: 100%|██████████| 100/100 [00:00<00:00, 113.49it/s]
# Epoch 1/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 24s 837ms/step - accuracy: 0.1168 - loss: 3.1837 - val_accuracy: 0.1450 - val_loss: 2.2178
# Epoch 2/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 40s 828ms/step - accuracy: 0.2062 - loss: 2.1386 - val_accuracy: 0.2650 - val_loss: 1.9388
# Epoch 3/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 41s 819ms/step - accuracy: 0.3666 - loss: 1.8357 - val_accuracy: 0.4200 - val_loss: 1.6244
# Epoch 4/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 19s 759ms/step - accuracy: 0.5161 - loss: 1.4317 - val_accuracy: 0.5100 - val_loss: 1.4688
# Epoch 5/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 21s 846ms/step - accuracy: 0.6103 - loss: 1.1595 - val_accuracy: 0.5550 - val_loss: 1.3476
# Epoch 6/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 19s 762ms/step - accuracy: 0.7015 - loss: 0.9124 - val_accuracy: 0.5500 - val_loss: 1.3055
# Epoch 7/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 21s 811ms/step - accuracy: 0.7601 - loss: 0.7117 - val_accuracy: 0.5050 - val_loss: 1.4874
# Epoch 8/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 19s 747ms/step - accuracy: 0.8219 - loss: 0.5773 - val_accuracy: 0.5600 - val_loss: 1.4164
# Epoch 9/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 22s 802ms/step - accuracy: 0.8653 - loss: 0.4073 - val_accuracy: 0.5400 - val_loss: 1.5119
# Epoch 10/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 19s 756ms/step - accuracy: 0.9278 - loss: 0.2773 - val_accuracy: 0.5550 - val_loss: 1.5108
# Epoch 11/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 22s 809ms/step - accuracy: 0.9616 - loss: 0.1568 - val_accuracy: 0.5700 - val_loss: 1.6079
# Epoch 12/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 19s 745ms/step - accuracy: 0.9711 - loss: 0.1307 - val_accuracy: 0.5250 - val_loss: 1.6171
# Epoch 13/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 22s 788ms/step - accuracy: 0.9788 - loss: 0.1108 - val_accuracy: 0.5850 - val_loss: 1.6619
# Epoch 14/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 19s 762ms/step - accuracy: 0.9875 - loss: 0.0698 - val_accuracy: 0.5350 - val_loss: 2.0158
# Epoch 15/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 20s 793ms/step - accuracy: 0.9767 - loss: 0.0701 - val_accuracy: 0.5650 - val_loss: 1.7816
# Epoch 16/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 19s 764ms/step - accuracy: 0.9736 - loss: 0.0880 - val_accuracy: 0.5600 - val_loss: 1.6756
# Epoch 17/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 21s 764ms/step - accuracy: 0.9806 - loss: 0.0700 - val_accuracy: 0.5450 - val_loss: 2.0776
# Epoch 18/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 22s 827ms/step - accuracy: 0.9935 - loss: 0.0509 - val_accuracy: 0.5250 - val_loss: 1.8654
# Epoch 19/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 41s 817ms/step - accuracy: 0.9951 - loss: 0.0423 - val_accuracy: 0.5500 - val_loss: 1.8612
# Epoch 20/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 19s 754ms/step - accuracy: 0.9934 - loss: 0.0370 - val_accuracy: 0.5300 - val_loss: 1.9677
# Epoch 21/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 22s 791ms/step - accuracy: 0.9932 - loss: 0.0268 - val_accuracy: 0.5550 - val_loss: 1.9611
# Epoch 22/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 19s 746ms/step - accuracy: 0.9931 - loss: 0.0299 - val_accuracy: 0.5400 - val_loss: 2.1453
# Epoch 23/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 22s 778ms/step - accuracy: 0.9968 - loss: 0.0301 - val_accuracy: 0.5550 - val_loss: 2.2111
# Epoch 24/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 21s 827ms/step - accuracy: 0.9911 - loss: 0.0352 - val_accuracy: 0.5550 - val_loss: 1.9360
# Epoch 25/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 41s 822ms/step - accuracy: 0.9985 - loss: 0.0146 - val_accuracy: 0.5450 - val_loss: 2.1412
# Epoch 26/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 41s 826ms/step - accuracy: 0.9969 - loss: 0.0167 - val_accuracy: 0.5450 - val_loss: 2.1501
# Epoch 27/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 40s 776ms/step - accuracy: 0.9985 - loss: 0.0154 - val_accuracy: 0.5550 - val_loss: 2.1417
# Epoch 28/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 23s 872ms/step - accuracy: 0.9968 - loss: 0.0190 - val_accuracy: 0.5800 - val_loss: 2.2229
# Epoch 29/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 19s 767ms/step - accuracy: 0.9898 - loss: 0.0357 - val_accuracy: 0.5600 - val_loss: 2.0772
# Epoch 30/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 22s 825ms/step - accuracy: 0.9980 - loss: 0.0157 - val_accuracy: 0.5150 - val_loss: 2.3703
# Epoch 31/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 40s 771ms/step - accuracy: 0.9982 - loss: 0.0129 - val_accuracy: 0.5650 - val_loss: 2.4683
# Epoch 32/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 20s 797ms/step - accuracy: 1.0000 - loss: 0.0127 - val_accuracy: 0.5700 - val_loss: 2.3980
# Epoch 33/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 20s 777ms/step - accuracy: 0.9981 - loss: 0.0090 - val_accuracy: 0.5500 - val_loss: 2.4552
# Epoch 34/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 21s 847ms/step - accuracy: 0.9999 - loss: 0.0070 - val_accuracy: 0.5700 - val_loss: 2.2995
# Epoch 35/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 20s 785ms/step - accuracy: 0.9965 - loss: 0.0149 - val_accuracy: 0.5350 - val_loss: 2.3107
# Epoch 36/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 21s 842ms/step - accuracy: 0.9988 - loss: 0.0182 - val_accuracy: 0.5400 - val_loss: 2.2813
# Epoch 37/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 19s 782ms/step - accuracy: 1.0000 - loss: 0.0059 - val_accuracy: 0.5450 - val_loss: 2.4746
# Epoch 38/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 22s 836ms/step - accuracy: 0.9972 - loss: 0.0103 - val_accuracy: 0.5500 - val_loss: 2.4110
# Epoch 39/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 19s 782ms/step - accuracy: 0.9994 - loss: 0.0076 - val_accuracy: 0.5000 - val_loss: 2.8267
# Epoch 40/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 22s 844ms/step - accuracy: 0.9914 - loss: 0.0268 - val_accuracy: 0.5250 - val_loss: 2.3965
# Epoch 41/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 40s 788ms/step - accuracy: 0.9982 - loss: 0.0119 - val_accuracy: 0.5500 - val_loss: 2.8162
# Epoch 42/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 20s 822ms/step - accuracy: 0.9927 - loss: 0.0322 - val_accuracy: 0.5450 - val_loss: 2.4318
# Epoch 43/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 41s 837ms/step - accuracy: 0.9985 - loss: 0.0128 - val_accuracy: 0.5550 - val_loss: 2.6332
# Epoch 44/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 41s 809ms/step - accuracy: 0.9895 - loss: 0.0361 - val_accuracy: 0.5600 - val_loss: 2.1681
# Epoch 45/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 40s 784ms/step - accuracy: 0.9976 - loss: 0.0176 - val_accuracy: 0.5400 - val_loss: 2.4516
# Epoch 46/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 22s 837ms/step - accuracy: 0.9978 - loss: 0.0096 - val_accuracy: 0.5750 - val_loss: 2.4262
# Epoch 47/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 40s 782ms/step - accuracy: 1.0000 - loss: 0.0119 - val_accuracy: 0.5550 - val_loss: 2.6161
# Epoch 48/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 22s 861ms/step - accuracy: 0.9928 - loss: 0.0136 - val_accuracy: 0.5700 - val_loss: 2.4313
# Epoch 49/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 40s 837ms/step - accuracy: 0.9981 - loss: 0.0157 - val_accuracy: 0.5450 - val_loss: 2.5765
# Epoch 50/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 40s 776ms/step - accuracy: 0.9962 - loss: 0.0171 - val_accuracy: 0.5350 - val_loss: 2.7036
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 203ms/step - accuracy: 0.5197 - loss: 2.7765
# ✅ Test accuracy: 0.5350
